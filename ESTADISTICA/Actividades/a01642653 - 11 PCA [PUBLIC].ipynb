# %% [markdown]
# # PRINCIPAL COMPONENT ANALISYS (PCA)
#
# Supongamos que la matriz de datos **X** es de dimensiones **num_observaciones** x **num_características**.
#
# En este caso en particular, nosotros generamos datos sinteticos (datos ficticios) dada una distribucion normal.

# %%
import matplotlib.pyplot as plt
import numpy as np

n_samples = 500
cov = [[3, 3, 1],
       [3, 4, 1],
       [1, 1, 1]]

X = np.random.multivariate_normal(mean=[0, 0, 0], cov=cov, size=n_samples)

print(f"Dimension del conjunto de datos generado: {X.shape}")
# Out:
# Dimension del conjunto de datos generado: (500, 3)

# %% [markdown]
# A manera de ejemplo, generamos datos de 3 dimensiones. De esta manera podemos generar el grafico de como se ven estos datos.

# %%
import plotly.graph_objects as go
import plotly.express as px

def plot_3D(X, Var_arrow=np.array([])):
  marker_data = go.Scatter3d(x=X[:,0],
                             y=X[:,1],
                             z=X[:,2],
                             mode='markers',
                             name="Data",
                             marker=dict(size=2,
                                         colorscale='Viridis',
                                         opacity=0.75))
  layout = go.Layout(title= '3-D Plane',
                     scene = dict(xaxis = dict(title  = "x"),
                                  yaxis = dict(title  = "y"),
                                  zaxis = dict(title  = "z")))

  arrow_data = []
  for i in range(Var_arrow.shape[0]):
    arrow_data.append(go.Scatter3d(x=[0, Var_arrow[i,0]],
                                    y=[0, Var_arrow[i,1]],
                                    z=[0, Var_arrow[i,2]],
                                    mode='lines',
                                    name=f"Componente {i+1}",
                                    line=dict(width=5)))

  fig=go.Figure(data=[marker_data, *arrow_data], layout=layout)

  fig.show()

# %%
plot_3D(X)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="59554720-d019-4057-93d9-e91fdef5e1e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59554720-d019-4057-93d9-e91fdef5e1e9")) {                    Plotly.newPlot(                        "59554720-d019-4057-93d9-e91fdef5e1e9",                        [{"marker":{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.75,"size":2},"mode":"markers","name":"Data","x":[0.29600721588200996,-3.00316025923924,1.6625059356357523,0.024314963884459816,-2.281749083795866,-0.846636683489684,1.1885992063376445,4.215300311130984,2.2448453833270854,1.3498378571488712,-0.0704208750523024,-0.05164179886111032,0.6312967648266425,0.48559477060273293,-0.06714427372983212,-4.461350672307489,-1.8331187774593438,-1.9402047851670123,3.0841699715567557,1.05658379295203,0.4636832255660125,2.7939133976797668,3.146156944700373,0.07199093317631423,0.3123092443206444,1.512770638279921,1.553586809713564,-2.713497502197649,1.9844177503962972,-0.20802195308607488,-1.327612394922495,0.9874505368399685,-1.1418141171189249,1.3013595128508397,1.0039244351661194,-0.4379178847988896,1.0088749692770558,-0.8231504662704581,0.44757345417449457,-0.7794614089273876,0.07882699706390225,-0.7628150534303162,-0.9692469362555209,0.5554751764123057,-2.20799182708578,-0.6420091193018056,0.01932017931744545,1.96160332783695,-0.36464779335902064,0.9875562345108547,1.8018638971894843,-0.11397654094111154,0.5629446071512163,1.6804979502869826,-2.5654993401649935,1.1088059510517143,2.1459222459076317,-0.015013961547575972,-1.6142107183172119,-3.694291905959933,-0.3423906547068231,3.6172001033531815,-0.37963318035624793,-0.5344539289454162,1.9325130950593183,-0.22327420357822858,0.8807266335613063,0.3212106217730105,0.27068722937184275,0.609448973618321,-0.8420304938619885,-0.06977752024108713,1.1563834354397793,1.4424039647282616,1.588516154561673,-0.04759099246929859,-1.7725110993044086,0.013692678984882519,2.483964580372307,-2.6329700332080077,-1.849831722625036,-0.508207760087222,-2.601663970503467,-1.5390625659694261,1.322689558833061,0.19147038422806967,2.0629916806384845,-1.3780859315804868,-2.606715699224746,-1.6678461646372014,1.2470847741660351,0.010545331523778047,1.6967441611307974,-1.202387918229143,3.405376321336256,0.9310754946933081,0.516431458797519,2.096561636234617,0.4991590210637138,-1.5707492778240006,-1.0945226540030388,-0.8101836923946373,0.5857270828330702,-3.0034816034364873,0.703209678831707,-0.11452210507968925,1.7602176719638865,-1.4802497596665398,-1.9464746383461333,2.080126116228336,2.723119543573804,-1.6082976379060536,-2.0422885312274306,-0.5229729454535442,-0.011586776072009902,-0.06489414187660351,0.6603161864402004,-1.2665694758278219,-1.2269011112139325,-2.4128066259288663,0.355108424814202,0.23596247732378373,3.724024898026258,-0.9255374951029435,-2.9666253587419917,-1.5342310948870157,0.22175941025632173,-1.6320854687445485,-1.3380471926206923,0.998012009692671,0.47499225487003544,-1.5947617237755016,0.22788954088844,0.02963134038847286,-1.125534900721606,0.23225352177622055,-1.0175633553403434,-1.329492666590123,-0.9095293412193579,3.6938731513830243,1.077538417002591,1.0234666510665773,3.009638023900838,1.114022773961,0.29656352266769065,0.8705787678569207,-1.388807510224599,0.4553138311718018,-2.418745417497503,0.8618565408775751,2.7336079428572244,-0.24533686108076716,-2.9361025408503605,1.623271776009642,1.7631338972022916,-0.28811411156587585,1.761366664273698,-2.0692003456396932,1.7924 ...

# %% [markdown]
# # ¿Cómo funciona el análisis de componentes principales (PCA)?
#
# Como ya se ha mencionado, el **análisis de componentes principales** es un algoritmo de reducción de la dimensionalidad. Esto significa que reduce la dimensionalidad del espacio de características. Pero, **¿cómo consigue esta reducción?**
#
# La motivación del algoritmo es que hay ciertas características que capturan un gran porcentaje de la varianza en el conjunto de datos original. Por eso es importante **encontrar las direcciones de máxima varianza en el conjunto de datos**. Estas direcciones se denominan componentes principales. **PCA** es esencialmente una proyección del conjunto de datos sobre los componentes principales.

# %% [markdown]
# # Realizar PCA en el conjunto de datos
#
# Para encontrar los componentes principales, podemos utilizar la clase **PCA** del módulo de descomposición de **scikit-learn**.
#
#
# Vamos a llamar a la funcion PCA pasando el número de componentes principales **n_components** deseados.
#
#
# El número de componentes principales es el número de dimensiones que le gustaría reducir el espacio de características (dimensiones). Por el momento no buscamos reducir las dimensiones, sino ver todos sus los componentes. En este caso, son 3 componentes principales ya que los datos estan en 3 dimensiones.

# %%
from sklearn.decomposition import PCA

# Elegir el numero de componentes
pca = PCA(n_components=3).fit(X)

# %% [markdown]
# La instancia de PCA pca que hemos creado tiene varios atributos útiles que nos ayudan a entender lo que está pasando bajo el capó.
#
# * El atributo **components_** almacena las direcciones de máxima varianza (los componentes principales).
#
# Hemos mencionado que los componentes principales son direcciones de máxima varianza en el conjunto de datos. Pero, **¿cómo medimos la magnitud en esa dirección?**
#
# * El atributo **explained_variance_** almacena las magnitud de varianza de los componentes principales.

# %%
print("Componentess con maxima varianza:")
for i,c in enumerate(pca.components_):
  print(f"Componente {i} = {c}")

print("\nMagnitud de varianza explicado por cada uno de los componentes seleccionados:")
for i,m in enumerate(pca.explained_variance_):
  print(f"Magnitud del componente {i} = {m}")
# Out:
# Componentess con maxima varianza:
# Componente 0 = [0.63307499 0.73725214 0.23595621]
# Componente 1 = [ 0.09231866 -0.37454987  0.9225994 ]
# Componente 2 = [ 0.76856575 -0.56229145 -0.30518029]
#
# Magnitud de varianza explicado por cada uno de los componentes seleccionados:
# Magnitud del componente 0 = 6.769987641462127
# Magnitud del componente 1 = 0.6642611813579948
# Magnitud del componente 2 = 0.4477251164025469

# %% [markdown]
# De una manera mas simple, el atributo **explained_variance_ratio_** captura la proporción de la varianza total que captura cada componente principal. De esta manera se puede sumar los ratios para obtener la varianza total en el número elegido de componentes.

# %%
for i, n in enumerate(np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)):
  print(f"componente {i}: {n}%")
# Out:
# componente 0: 85.89%
# componente 1: 94.32%
# componente 2: 100.0%

# %% [markdown]
# Aquí vemos que el **primer componente principal** captura el **86.16%** de la varianza de los datos, los primeros **dos componentes principales** juntos ccapturan el **94.43%** y los **tres componentes principales** capturan el **100%** de la varianza total del conjunto de datos.

# %% [markdown]
# ---
# Asi pues, podemos visualizar sobre los datos originales la direccion y magnitud de sus componentes principales, que muestran los ejes principales por los que se distribuyen los datos.

# %%
plot_3D(X, Var_arrow=np.dot(np.diag(pca.explained_variance_), pca.components_))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="867353ff-05ea-4210-9c8c-03d3a542810b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("867353ff-05ea-4210-9c8c-03d3a542810b")) {                    Plotly.newPlot(                        "867353ff-05ea-4210-9c8c-03d3a542810b",                        [{"marker":{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.75,"size":2},"mode":"markers","name":"Data","x":[0.4181787525338557,1.2924374953735072,-0.23204890994949245,1.224979367952655,0.2278852465068356,0.3993886433626777,-1.582438359250511,1.9487517196381823,-0.9626850742137557,1.4492733855820703,-0.7739474446527271,-3.131147500404197,-1.779496998891931,-2.0523318075534744,-0.9419012039184623,-1.4165558114381323,2.456301875061505,4.074033401419152,3.8176697642849335,-3.2349169039728283,-1.5158166023462827,0.7466432089244929,-0.1743202882806436,-0.19438404169012066,-2.1909255395910785,0.11732562926884033,2.365700539318925,-2.9414205171402035,-1.0674785584440913,-1.396302245472412,0.47774607058989066,3.5691875610153683,-0.624300023654367,0.6215615523197008,0.030864923457968995,-0.9129281403987983,1.1557740849123548,-0.06874123363691684,0.20885755338085052,0.8413131150285167,0.4890477464993059,-1.6455406220422475,-1.4029347569996151,-1.3552911786630795,1.2531424575557173,0.31761976294352845,-3.2779253964251187,2.8615975881000697,-0.3569279773573403,-1.1543950591171446,-0.031547051186429115,-2.755415923635932,-0.4387937451077318,2.2659986639167333,-1.2971742777398334,3.055883941613631,-0.3416527041962659,-3.329973386999101,3.738991009786045,1.6989048503766795,-0.6824958621084634,-1.9475995617418758,0.44646453964571,2.2381862357876847,-4.133669608173438,-1.4448392793499112,-1.7027191967356923,2.00376303775744,0.13995850881573593,1.5952927480555634,-1.6612662423938878,-1.115929211223261,0.5546271899686845,-2.547102453642063,1.9434821897067749,0.5926484078510909,-0.27373713196689253,-0.3283112311399031,3.835806456030294,0.36849232299915474,1.170790710089446,1.909579726413131,0.34852739493377644,0.28790676320224645,-0.3696035836428814,-1.7335660634979067,-1.1266923074529434,-2.049543747229357,-0.9070196290136665,1.5213647952619005,-2.5058633202539573,-1.158406731840149,-2.655178741549402,-0.28753346185782264,0.4455560273872933,-0.7960748748633913,0.7739335162321173,-1.3447582639004523,0.9273502764512388,-0.03935871804066323,-0.5698223292993466,-0.051882598302802854,3.3372965110008224,-0.7495075361250845,1.4202507954798196,1.0851679058401829,0.49670183183631555,-0.19281760809644818,1.5215489838565368,-1.0326636402842442,1.1978609041999313,1.4600492004825434,1.5163830251341466,0.16861986287758962,-0.651473117513019,0.35683192010088516,0.9272510946083752,1.676631892628942,0.4193754299540068,1.2570361796336147,-2.326620021728023,-1.500621732921613,1.149288450166131,-1.228467292055897,-1.7332248014036873,2.045396507041794,-0.1482592089678916,-2.8731131659230127,-1.3447959511737473,-3.7654137915375063,0.17654499147698358,1.8872707963811906,1.4216316950834236,0.19407791483909154,0.4636518006991322,-0.5080992921310021,-1.0598682119426983,-1.3551367424425993,-1.5124448076741472,-1.6866942268851073,0.7947519191573562,1.0364243363484318,0.12593334472314138,-0.5061118046974461,2.492306569031389,-2.8915405933034086,0.796292501326874,-1.8504627746175124,0.968080667333774,-1.2917556597763258,-0.4048294946422656,-1.2397212080236863,-1.86017734665461,-0.9121478595315735,0.8918644590543563,-1.747996667344397,-0.5852182767517499,-0.696928969712 ...

# %% [markdown]
# ---
# # Realizar PCA para reducir la dimension de los datos (ahora si)
#
# Se puede llamar a la funcion **fit_transform()**, que realiza la funcion **fit()**, que ajusta el modelo con los datos X, seguido de la funcion **transform()**, que aplica la reducción de dimensionalidad a los datos X.
#
# En este caso vamos a reducir la dimensionalidad de nuestros datos de 3-D a 2-D.

# %%
pca_red = PCA(n_components=2)

X_pca = pca_red.fit_transform(X)

print(f"Nuevas dimensiones de los datos: {X_pca.shape}")
# Out:
# Nuevas dimensiones de los datos: (500, 2)

# %%
print("Componentess con maxima varianza:")
for i,c in enumerate(pca_red.components_):
  print(f"Componente {i} = {c}")
# Out:
# Componentess con maxima varianza:
# Componente 0 = [0.63307499 0.73725214 0.23595621]
# Componente 1 = [ 0.09231866 -0.37454987  0.9225994 ]

# %%
print("\nMagnitud de varianza explicado por cada uno de los componentes seleccionados:")
for i,m in enumerate(pca_red.explained_variance_):
  print(f"Magnitud del componente {i} = {m}")
# Out:
# Magnitud de varianza explicado por cada uno de los componentes seleccionados:
# Magnitud del componente 0 = 6.769987641462127
# Magnitud del componente 1 = 0.6642611813579948

# %% [markdown]
# Dependiendo cuantos componentes principales elegimos (en estes caso, 2), podemos realizar una grafica que muestre nuestros datos reducidos en dimensionalidad.

# %%
def plot_2D(X, Var_arrow=np.array([])):
  plt.figure(figsize=(15,15))

  plt.scatter(X[:, 0], X[:, 1], alpha=0.75, label="data_reduced")

  for i in range(Var_arrow.shape[0]):
    plt.plot([0, Var_arrow[i,0]], [0, Var_arrow[i,1]],
             label=f"Component {i+1}",
             linewidth=3,
             color=f"C{i + 2}")

  plt.gca().set(aspect='equal',
                adjustable='box',
                title="2-D Plane",
                xlabel="x",
                ylabel="y",)
  plt.grid()
  plt.legend()
  plt.show()

# %%
# Obtenemos los nuevos componentes de los datos ya transformados
pca_red = pca_red.fit(X_pca)

# Graficamos
plot_2D(X_pca, Var_arrow=np.dot(np.diag(pca_red.explained_variance_), pca_red.components_))

# %% [markdown]
# ---
# ---
#
# # EJERCIO: PCA & SVD
#
# En este ejercicio se pide replicar los resultados obtenidos con nuestra implementacion de PCA de **`sklearn`**. Implementa manualmente el proceso para reducir a 2 dimensiones el conjunto de datos original 3D.
#
# **Recordemos los datos originales:**

# %%
N = X.shape
print(f"Dimensiones datos: {N}")
plot_3D(X)
# Out:
# Dimensiones datos: (500, 3)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f110d54-9755-48b7-bbfd-13accc94adc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f110d54-9755-48b7-bbfd-13accc94adc2")) {                    Plotly.newPlot(                        "7f110d54-9755-48b7-bbfd-13accc94adc2",                        [{"marker":{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.75,"size":2},"mode":"markers","name":"Data","x":[0.4181787525338557,1.2924374953735072,-0.23204890994949245,1.224979367952655,0.2278852465068356,0.3993886433626777,-1.582438359250511,1.9487517196381823,-0.9626850742137557,1.4492733855820703,-0.7739474446527271,-3.131147500404197,-1.779496998891931,-2.0523318075534744,-0.9419012039184623,-1.4165558114381323,2.456301875061505,4.074033401419152,3.8176697642849335,-3.2349169039728283,-1.5158166023462827,0.7466432089244929,-0.1743202882806436,-0.19438404169012066,-2.1909255395910785,0.11732562926884033,2.365700539318925,-2.9414205171402035,-1.0674785584440913,-1.396302245472412,0.47774607058989066,3.5691875610153683,-0.624300023654367,0.6215615523197008,0.030864923457968995,-0.9129281403987983,1.1557740849123548,-0.06874123363691684,0.20885755338085052,0.8413131150285167,0.4890477464993059,-1.6455406220422475,-1.4029347569996151,-1.3552911786630795,1.2531424575557173,0.31761976294352845,-3.2779253964251187,2.8615975881000697,-0.3569279773573403,-1.1543950591171446,-0.031547051186429115,-2.755415923635932,-0.4387937451077318,2.2659986639167333,-1.2971742777398334,3.055883941613631,-0.3416527041962659,-3.329973386999101,3.738991009786045,1.6989048503766795,-0.6824958621084634,-1.9475995617418758,0.44646453964571,2.2381862357876847,-4.133669608173438,-1.4448392793499112,-1.7027191967356923,2.00376303775744,0.13995850881573593,1.5952927480555634,-1.6612662423938878,-1.115929211223261,0.5546271899686845,-2.547102453642063,1.9434821897067749,0.5926484078510909,-0.27373713196689253,-0.3283112311399031,3.835806456030294,0.36849232299915474,1.170790710089446,1.909579726413131,0.34852739493377644,0.28790676320224645,-0.3696035836428814,-1.7335660634979067,-1.1266923074529434,-2.049543747229357,-0.9070196290136665,1.5213647952619005,-2.5058633202539573,-1.158406731840149,-2.655178741549402,-0.28753346185782264,0.4455560273872933,-0.7960748748633913,0.7739335162321173,-1.3447582639004523,0.9273502764512388,-0.03935871804066323,-0.5698223292993466,-0.051882598302802854,3.3372965110008224,-0.7495075361250845,1.4202507954798196,1.0851679058401829,0.49670183183631555,-0.19281760809644818,1.5215489838565368,-1.0326636402842442,1.1978609041999313,1.4600492004825434,1.5163830251341466,0.16861986287758962,-0.651473117513019,0.35683192010088516,0.9272510946083752,1.676631892628942,0.4193754299540068,1.2570361796336147,-2.326620021728023,-1.500621732921613,1.149288450166131,-1.228467292055897,-1.7332248014036873,2.045396507041794,-0.1482592089678916,-2.8731131659230127,-1.3447959511737473,-3.7654137915375063,0.17654499147698358,1.8872707963811906,1.4216316950834236,0.19407791483909154,0.4636518006991322,-0.5080992921310021,-1.0598682119426983,-1.3551367424425993,-1.5124448076741472,-1.6866942268851073,0.7947519191573562,1.0364243363484318,0.12593334472314138,-0.5061118046974461,2.492306569031389,-2.8915405933034086,0.796292501326874,-1.8504627746175124,0.968080667333774,-1.2917556597763258,-0.4048294946422656,-1.2397212080236863,-1.86017734665461,-0.9121478595315735,0.8918644590543563,-1.747996667344397,-0.5852182767517499,-0.696928969712 ...

# %% [markdown]
# * **Completa la funcion `SVD` para obtener los componentes originales y sus magnitudes (eigenvalores)**
# * **Asegurate de realizar el preprocesamiento a los datos previo a la descomposicion**

# %%
from scipy import linalg

def SVD(X):
  """
  Regresa la descomposicion de la matriz de covarianza de los datos originales X:
  componentes (eigenvectores) y sus magnitudes (eigenvalores).
  Args:
      X (np.ndarray): Matriz de características (n_samples, n_features).
  Returns:
      np.ndarray: componentes (n_features, n_features), magnitudes (n_features, ).
  """
  # Tu codigo va aqui
  # Center the data
  X_centered = X - np.mean(X, axis=0)

  # Calculate the covariance matrix
  cov_matrix = np.cov(X_centered, rowvar=False)

  # Perform SVD on the covariance matrix
  U, s, Vh = linalg.svd(cov_matrix)

  # The eigenvalues are the singular values squared
  eigenvalues = s**2

  # The eigenvectors are the columns of U or rows of Vh (depending on convention)
  # In this case, Vh are the eigenvectors
  eigenvectors = Vh

  return eigenvectors, eigenvalues

# %%
# Obtain components and magnitudes using the SVD function
components, magnitudes = SVD(X)

print("Componentes (eigenvectores):")
for i, c in enumerate(components):
  print(f"Componente {i} = {c}")
# Out:
# Componentes (eigenvectores):
# Componente 0 = [-0.63307499 -0.73725214 -0.23595621]
# Componente 1 = [-0.09231866  0.37454987 -0.9225994 ]
# Componente 2 = [ 0.76856575 -0.56229145 -0.30518029]

# %%
print("\nMagnitud de varianza explicado por cada uno de los componentes (eigenvalores):")
for i, m in enumerate(magnitudes):
  print(f"Magnitud del componente {i} = {m}")
# Out:
# Magnitud de varianza explicado por cada uno de los componentes (eigenvalores):
# Magnitud del componente 0 = 45.83273266554989
# Magnitud del componente 1 = 0.44124291705911745
# Magnitud del componente 2 = 0.200457779857676

# %% [markdown]
# *   **Utilizando las magnitudes de los componentes, muestra la proporción de la varianza total que captura cada componente principal. Expresalo en porcentajes.**
# * Vale la pena preguntarse si los componentes ya vienen ordenamos de manera descendente.

# %%
# Calculate and print the explained variance ratio
explained_variance_ratio = magnitudes / np.sum(magnitudes)

print("Proporción de la varianza total que captura cada componente principal:")
for i, ratio in enumerate(explained_variance_ratio):
  print(f"Componente {i}: {ratio:.4f}%")

print("\nVarianza acumulada:")
cumulative_variance = np.cumsum(explained_variance_ratio)
for i, cum_ratio in enumerate(cumulative_variance):
  print(f"Componente {i}: {cum_ratio:.4f}%")

# Check if components are ordered by magnitude (they should be by default in SVD)
print("\n¿Los componentes están ordenados por magnitud de manera descendente?")
print(np.all(magnitudes[:-1] >= magnitudes[1:]))
# Out:
# Proporción de la varianza total que captura cada componente principal:
# Componente 0: 0.9862%
# Componente 1: 0.0095%
# Componente 2: 0.0043%
#
# Varianza acumulada:
# Componente 0: 0.9862%
# Componente 1: 0.9957%
# Componente 2: 1.0000%
#
# ¿Los componentes están ordenados por magnitud de manera descendente?
# True

# %% [markdown]
# * **Nuevamente, utiliza las magnitudes y los componentes mismos para calcular los vectores de la varianza de los datos originales X. Utilizando la funcion `plot_3D`, grafica los datos originales X y los vectores de la varianza.**
# * En la descomposición SVD, si $𝑞$ es un eigenvector asociado a un eigenvalor $𝜆$, entonces $−𝑞$ también lo es. Esto puede hacer que la direccion de los vectores de varianza difiera respecto a la implementacion de **`sklearn`**. Para eso, utiliza la funcion **`fix_signs`** para asegurarnos de tener los mismos signos. Asegurate de guarda la matriz de componentes arreglada en una variable aparte.

# %%
def fix_signs(V, V_ref):
  """
  Regresa Matriz de componentes con signo arreglado respecto a la obtenida en la implementacion sklearn.
  Args:
      V (np.ndarray): Matriz de componentes (n_componentes, n_features).
      V_ref (np.ndarray): Matriz de componentes de implementacion sklearn (n_componentes, n_features).
  Returns:
      np.ndarray: Matriz de componentes con signo arreglado (n_componentes, n_features).
  """
  V_fixed = V.copy()
  for i in range(V.shape[0]):
    if np.sign(V_ref[i, i]) != np.sign(V_fixed[i, i]):
      V_fixed[i, :] *= -1
  return V_fixed

# %%
# Fix the signs of the components using the fix_signs function and sklearn's components as reference
pca = PCA(n_components=3).fit(X)
components_sklearn = pca.components_
components_fixed = fix_signs(components, components_sklearn)

print("Componentes con signo arreglado:")
for i, c in enumerate(components_fixed):
  print(f"Componente {i} = {c}")
# Out:
# Componentes con signo arreglado:
# Componente 0 = [0.63307499 0.73725214 0.23595621]
# Componente 1 = [ 0.09231866 -0.37454987  0.9225994 ]
# Componente 2 = [ 0.76856575 -0.56229145 -0.30518029]

# %%
# Calculate variance vectors using fixed components and magnitudes
variance_vectors = np.dot(np.diag(magnitudes), components_fixed)

# Plot the original data and variance vectors
plot_3D(X, Var_arrow=variance_vectors)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b927a495-7f3e-434d-b4c2-d0c3134252d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b927a495-7f3e-434d-b4c2-d0c3134252d6")) {                    Plotly.newPlot(                        "b927a495-7f3e-434d-b4c2-d0c3134252d6",                        [{"marker":{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.75,"size":2},"mode":"markers","name":"Data","x":[0.4181787525338557,1.2924374953735072,-0.23204890994949245,1.224979367952655,0.2278852465068356,0.3993886433626777,-1.582438359250511,1.9487517196381823,-0.9626850742137557,1.4492733855820703,-0.7739474446527271,-3.131147500404197,-1.779496998891931,-2.0523318075534744,-0.9419012039184623,-1.4165558114381323,2.456301875061505,4.074033401419152,3.8176697642849335,-3.2349169039728283,-1.5158166023462827,0.7466432089244929,-0.1743202882806436,-0.19438404169012066,-2.1909255395910785,0.11732562926884033,2.365700539318925,-2.9414205171402035,-1.0674785584440913,-1.396302245472412,0.47774607058989066,3.5691875610153683,-0.624300023654367,0.6215615523197008,0.030864923457968995,-0.9129281403987983,1.1557740849123548,-0.06874123363691684,0.20885755338085052,0.8413131150285167,0.4890477464993059,-1.6455406220422475,-1.4029347569996151,-1.3552911786630795,1.2531424575557173,0.31761976294352845,-3.2779253964251187,2.8615975881000697,-0.3569279773573403,-1.1543950591171446,-0.031547051186429115,-2.755415923635932,-0.4387937451077318,2.2659986639167333,-1.2971742777398334,3.055883941613631,-0.3416527041962659,-3.329973386999101,3.738991009786045,1.6989048503766795,-0.6824958621084634,-1.9475995617418758,0.44646453964571,2.2381862357876847,-4.133669608173438,-1.4448392793499112,-1.7027191967356923,2.00376303775744,0.13995850881573593,1.5952927480555634,-1.6612662423938878,-1.115929211223261,0.5546271899686845,-2.547102453642063,1.9434821897067749,0.5926484078510909,-0.27373713196689253,-0.3283112311399031,3.835806456030294,0.36849232299915474,1.170790710089446,1.909579726413131,0.34852739493377644,0.28790676320224645,-0.3696035836428814,-1.7335660634979067,-1.1266923074529434,-2.049543747229357,-0.9070196290136665,1.5213647952619005,-2.5058633202539573,-1.158406731840149,-2.655178741549402,-0.28753346185782264,0.4455560273872933,-0.7960748748633913,0.7739335162321173,-1.3447582639004523,0.9273502764512388,-0.03935871804066323,-0.5698223292993466,-0.051882598302802854,3.3372965110008224,-0.7495075361250845,1.4202507954798196,1.0851679058401829,0.49670183183631555,-0.19281760809644818,1.5215489838565368,-1.0326636402842442,1.1978609041999313,1.4600492004825434,1.5163830251341466,0.16861986287758962,-0.651473117513019,0.35683192010088516,0.9272510946083752,1.676631892628942,0.4193754299540068,1.2570361796336147,-2.326620021728023,-1.500621732921613,1.149288450166131,-1.228467292055897,-1.7332248014036873,2.045396507041794,-0.1482592089678916,-2.8731131659230127,-1.3447959511737473,-3.7654137915375063,0.17654499147698358,1.8872707963811906,1.4216316950834236,0.19407791483909154,0.4636518006991322,-0.5080992921310021,-1.0598682119426983,-1.3551367424425993,-1.5124448076741472,-1.6866942268851073,0.7947519191573562,1.0364243363484318,0.12593334472314138,-0.5061118046974461,2.492306569031389,-2.8915405933034086,0.796292501326874,-1.8504627746175124,0.968080667333774,-1.2917556597763258,-0.4048294946422656,-1.2397212080236863,-1.86017734665461,-0.9121478595315735,0.8918644590543563,-1.747996667344397,-0.5852182767517499,-0.696928969712 ...

# %% [markdown]
# * **Transforma los datos originales `X` con la matriz de componentes `V`. Para realizar la reduccion de dimensionalidad basta con omitir algunos componentes y quedarnos solo con los componentes (dimensiones) que deseamos. Aqui, queremos reducir la dimension de los datos de 3D a 2D.**
# * Asegurate que al multiplicar $X$ y $V$ se tengan las dimensiones correctas.

# %%
# Transform the original data X using the fixed components
# We want to reduce the dimensionality from 3D to 2D, so we take the first 2 components
X_reduced = np.dot(X - np.mean(X, axis=0), components_fixed[:, :2])

print(f"Nuevas dimensiones de los datos: {X_reduced.shape}")
# Out:
# Nuevas dimensiones de los datos: (500, 2)

# %%
# Obtain components and magnitudes for the reduced data using the SVD function
components_reduced, magnitudes_reduced = SVD(X_reduced)

# Fix the signs of the components using the fix_signs function
# We need a reference for the signs. We can use PCA on the reduced data for this.
pca_reduced_ref = PCA(n_components=2).fit(X_reduced)
components_reduced_sklearn = pca_reduced_ref.components_
components_reduced_fixed = fix_signs(components_reduced, components_reduced_sklearn)

print("Componentes con signo arreglado (datos reducidos):")
for i, c in enumerate(components_reduced_fixed):
  print(f"Componente {i} = {c}")

print("\nMagnitud de varianza explicado por cada uno de los componentes (datos reducidos):")
for i, m in enumerate(magnitudes_reduced):
  print(f"Magnitud del componente {i} = {m}")
# Out:
# Componentes con signo arreglado (datos reducidos):
# Componente 0 = [0.99766754 0.06826036]
# Componente 1 = [-0.06826036  0.99766754]
#
# Magnitud de varianza explicado por cada uno de los componentes (datos reducidos):
# Magnitud del componente 0 = 10.560681429712588
# Magnitud del componente 1 = 0.22741609605776625

# %% [markdown]
# * Nuevamente aplica la funcion **`SVD`** para obtener los componentes y sus magnitudes de este nuevo conjunto de datos con dimensionalidad reducida. Nuevamente asegurate que los signos sean correctos usando la funcion **`fix_signs`**.
# * Utiliza la funcion **`plot_2D`** para graficar los datos reducidos y sus respectivos vectores de la varianza.

# %%
# Calculate variance vectors for the reduced data using fixed components and magnitudes
variance_vectors_reduced = np.dot(np.diag(magnitudes_reduced), components_reduced_fixed)

# Plot the reduced data and variance vectors
plot_2D(X_reduced, Var_arrow=variance_vectors_reduced)

# %%
# Compare with scikit-learn's PCA on the reduced data
pca_reduced_sklearn = PCA(n_components=2).fit(X_reduced)

print("\nComponentes (sklearn PCA en datos reducidos):")
for i, c in enumerate(pca_reduced_sklearn.components_):
  print(f"Componente {i} = {c}")

print("\nMagnitud de varianza explicado (sklearn PCA en datos reducidos):")
for i, m in enumerate(pca_reduced_sklearn.explained_variance_):
  print(f"Magnitud del componente {i} = {m}")
# Out:
# Componentes (sklearn PCA en datos reducidos):
# Componente 0 = [0.99766754 0.06826036]
# Componente 1 = [-0.06826036  0.99766754]
#
# Magnitud de varianza explicado (sklearn PCA en datos reducidos):
# Magnitud del componente 0 = 3.2497202079121497
# Magnitud del componente 1 = 0.47688163736693245

# %% [markdown]
# Notaras que las representaciones de los datos sean identica a los de la implementacion en **`sklearn`**.
